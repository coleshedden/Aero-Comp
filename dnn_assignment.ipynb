# %% [markdown]
# <span style="color:red;font-weight:700;font-size:40px">
#     Assignment 4 - DNNs with PyTorch
# </span>

# %%
from assignment import Assignment

# %% [markdown]
# # Question 1

# %%
# Call the model. Fill in the rest
model1 = Assignment()

# %%
# Plot the data set. One line of code
model1.data_set.plot()

# %%
# Block to input parameters. Five lines of code
model1.epochs = 151
model1.learning_rate = 0.19
model1.layers = [1, 1, 2, 1, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train()

# %%
# Check validation error. One line of code 
model1.validation()
# Out:
# Validation error for the trained model = 0.9243987876289772

# %%
# Run validation against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 0.9243987876289772
# Validation error against real data: 0.09593263185378476

# %% [markdown]
# # Question 2

# %% [markdown]
# # Effect of Neural Network depth

# %%
# Use one hidden layer. Keep the rest same as Question 1. Five lines of code
model1.epochs = 151
model1.learning_rate = 0.19
model1.layers = [1, 1, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# Set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train()

# %%
# Validate against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 1.0606411248793393
# Validation error against real data: 0.05287556147364847

# %% [markdown]
# # Effect of number of neurons

# %%
# Use one hidden layer. Increase the number of neurons to four times from question 1
# Keep the rest same as Question 1. Five lines of code
model1.epochs = 151
model1.learning_rate = 0.19
model1.layers = [1, 4, 8, 4, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# Set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train()

# %%
# Validate against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 1.0086539245425143
# Validation error against real data: 0.041672735043711606

# %% [markdown]
# # Solution 2c

# %% [markdown]
# # Train-test split effect

# %%
# Increase train set to 90%. Keep the rest same as Question 1. Five lines of code
model1.epochs = 151
model1.learning_rate = 0.19
model1.layers = [1, 1, 2, 1, 1]
model1.momentum = 0
model1.p_train = 0.9

# %%
# Set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train()

# %%
# Validate against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 1.1545540168850152
# Validation error against real data: 0.1516044205477698

# %% [markdown]
# # Effect of epochs

# %%
# Set epochs to 10. Keep the rest same as Question 1. Five lines of code
model1.epochs = 10
model1.learning_rate = 0.19
model1.layers = [1, 1, 2, 1, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# Set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train()

# %%
# Validate against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 1.0772375870925686
# Validation error against real data: 0.2113478907948272

# %%
# Set epochs to 2000. Keep the rest same as Question 1. Five lines of code
model1.epochs = 2000
model1.learning_rate = 0.19
model1.layers = [1, 1, 2, 1, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# Set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train()

# %%
# Validate against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 0.943465385620712
# Validation error against real data: 0.0844817767790298

# %% [markdown]
# # Effect of learning rate

# %%
# Set learning rate to 0.1. Keep the rest same as Question 1. Five lines of code
model1.epochs = 151
model1.learning_rate = 0.10
model1.layers = [1, 1, 2, 1, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# Set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train()

# %%
# Validate against real data. One line of code
model1.validation_real_data()
# Out:
# Validation error for the trained model = 0.9400839790859585
# Validation error against real data: 0.06848734462943185

# %%
# Set learning rate to 0.001. Keep the rest same as Question 1. Five lines of code
model1.epochs = 151
model1.learning_rate = 0.001
model1.layers = [1, 1, 2, 1, 1]
model1.momentum = 0
model1.p_train = 0.7

# %%
# Set parameters and train the model. Two lines of code
model1.set_parameters()
model1.train()

# %%
# Validate against real data. One line of code
model1.validation_real_data()

# %% [markdown]
# ### Fill in the following table. Replace "x" with numerics. Specify Underfit or Overfit in comparison to against Original Solution unless until specified otherwise

# %% [markdown]
# - Note: Double-click to edit

# %% [markdown]
# | Parameter            | Test Loss   | Validation Error |                                  Comment       |
# | :---                 |    :----:   |      :----:      |                                           ---: |
# | Original Sol.        |     1.13    |       0.92       |                                   Best Solution|
# | Layers - Low         |     1.11    |       1.06       |                                Overfit|
# | Neurons - High       |     1.07    |       1.01       |                                Overfit|
# | Train-Test           |     1.11    |       1.15       |                                Underfit|
# | Epochs - Low         |     1.81    |       1.08       |                                Overfit|
# | Epochs - High        |     1.07    |       0.94       |                                Underfit|
# | Learning Rate - Low  |     1.19    |       0.94      |                                Overfit|

# %% [markdown]
# ## Lowering the layers seemed to increase validation error but keep test loss relatively constant. Increasing the nuerons decreased test loss and increased validation error. Increasing train-test to 90% decreased test loss and increased validation error. Low epochs correlated to massive increases in test loss and increase in validation error. High epochs led to similar validation error and decreased test loss. Low learning rate increased both.
